# %%
import requests
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# %%
import requests

headers = {"Flic-Token": "flic_43217e0b7f06440efa28331bdc8c777150d194aa3df6a7515dc8bf0bfa1931cd"}

# Fetch data for viewed posts
viewed_posts = requests.get("https://api.socialverseapp.com/posts/view?page=1&page_size=1000&resonance_algorithm=resonance_algorithm_cjsvervb7dbhss8bdrj89s44jfjdbsjd0xnjkbvuire8zcjwerui3njfbvsujc5if", headers=headers).json()

inspire_posts = requests.get("https://api.socialverseapp.com/posts/inspire?page=1&page_size=1000&resonance_algorithm=resonance_algorithm_cjsvervb7dbhss8bdrj89s44jfjdbsjd0xnjkbvuire8zcjwerui3njfbvsujc5if",headers=headers).json()
# Fetch data for liked posts
liked_posts = requests.get("https://api.socialverseapp.com/posts/like?page=1&page_size=1000&resonance_algorithm=resonance_algorithm_cjsvervb7dbhss8bdrj89s44jfjdbsjd0xnjkbvuire8zcjwerui3njfbvsujc5if", headers=headers).json()

# Fetch user ratings
user_ratings = requests.get("https://api.socialverseapp.com/posts/rating?page=1&page_size=1000&resonance_algorithm=resonance_algorithm_cjsvervb7dbhss8bdrj89s44jfjdbsjd0xnjkbvuire8zcjwerui3njfbvsujc5if", headers=headers).json()

# %%
# Fetch posts metadata
posts_metadata = requests.get("https://api.socialverseapp.com/posts/summary/get?page=1&page_size=1000", headers=headers).json()

# Fetch user data
users_data = requests.get("https://api.socialverseapp.com/users/get_all?page=1&page_size=1000", headers=headers).json()

# %%
users_data
# Out:
# {'message': 'User not logged in', 'code': 'error', 'status': 401}

# %%
# Print the response to see its structure
print(viewed_posts)
print(inspire_posts)
print(liked_posts)
print(user_ratings)
# Out:
# {'status': 'success', 'message': 'Viewed posts fetched successfully', 'page': 1, 'page_size': 1000, 'max_page_size': 1000, 'posts': [{'id': 18, 'post_id': 631, 'user_id': 114, 'viewed_at': '2024-01-10 07:20:55'}, {'id': 19, 'post_id': 626, 'user_id': 114, 'viewed_at': '2024-01-10 07:21:18'}, {'id': 20, 'post_id': 571, 'user_id': 114, 'viewed_at': '2024-01-10 07:22:02'}, {'id': 22, 'post_id': 558, 'user_id': 116, 'viewed_at': '2024-01-10 12:33:47'}, {'id': 23, 'post_id': 551, 'user_id': 116, 'viewed_at': '2024-01-10 12:33:55'}, {'id': 24, 'post_id': 560, 'user_id': 116, 'viewed_at': '2024-01-10 12:34:06'}, {'id': 25, 'post_id': 588, 'user_id': 116, 'viewed_at': '2024-01-10 12:34:47'}, {'id': 32, 'post_id': 473, 'user_id': 44, 'viewed_at': '2024-01-11 18:32:10'}, {'id': 34, 'post_id': 633, 'user_id': 44, 'viewed_at': '2024-01-11 18:33:51'}, {'id': 35, 'post_id': 67, 'user_id': 44, 'viewed_at': '2024-01-11 18:38:57'}, {'id': 36, 'post_id': 66, 'user_id': 44, 'viewed_at': '2024-01-11 18:
# ...

# %%
import pandas as pd

# %%
inspires_df = pd.DataFrame(inspire_posts['posts'])

# %%
inspires_df.head()
# Out:
#    id  post_id  user_id          inspired_at
# 0   1      588        1  2023-12-31 09:06:27
# 1   2      152        1  2023-12-31 09:07:32
# 2   3      415        1  2023-12-31 09:10:09
# 3   4      558        1  2023-12-31 09:11:23
# 4   5      549        1  2023-12-31 09:11:28

# %%
viewed_df = pd.DataFrame(viewed_posts['posts'])
viewed_df.head()
# Out:
#    id  post_id  user_id            viewed_at
# 0  18      631      114  2024-01-10 07:20:55
# 1  19      626      114  2024-01-10 07:21:18
# 2  20      571      114  2024-01-10 07:22:02
# 3  22      558      116  2024-01-10 12:33:47
# 4  23      551      116  2024-01-10 12:33:55

# %%
liked_df=pd.DataFrame(liked_posts['posts'])
liked_df.head()
# Out:
#    id  post_id  user_id             liked_at
# 0   2       26        9  2023-10-24 19:28:41
# 1   3       33        9  2023-10-26 09:08:32
# 2   5       36        1  2023-10-28 09:08:35
# 3   7       36       16  2023-10-28 09:15:57
# 4   9       52        9  2023-10-30 15:48:46

# %%
user_rating_df = pd.DataFrame(user_ratings['posts'])
user_rating_df.head()
# Out:
#    id  post_id  user_id  rating_percent             rated_at
# 0   1      516        1              64  2024-01-11 12:45:41
# 1   2      160        1              62  2024-01-11 12:47:15
# 2   3       19        1              20  2024-01-11 12:47:28
# 3   4      148        1             100  2024-01-11 12:49:35
# 4   5      513        1              63  2024-01-11 12:50:58
